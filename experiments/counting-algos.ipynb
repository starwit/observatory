# %%
# Read tsp-area.csv with pandas and output a list of areas
import pandas as pd

AREA_FILE = 'tsp-area.csv'
LINE_FILE = 'tsp-line.csv'

# Parse occupancy_time to a timestamp and use occupandy_time as index
area_df = pd.read_csv(AREA_FILE)
area_df['occupancy_time'] = pd.to_datetime(area_df['occupancy_time'], format='ISO8601')
area_df = area_df.set_index('occupancy_time')

# %%
FILTER_AREAS = [
    'parking-meckauer-west01',
    'parking-meckauer-west02',
    'parking-meckauer-west03',
    'parking-meckauer-center',
    'parking-meckauer-center02',
    'parking-meckauer-ost01',
    'parking-meckauer-ost02',
]

# Make 10s buckets of area_df by occupancy_time and average the count in each bucket
area_df.resample('10min').mean(numeric_only=True)
# Out:
#                               count  object_class_id  metadata_id         id  \
# occupancy_time
# 2025-12-10 00:00:00+00:00  0.282353              2.0    16.952941  16.952941
# 2025-12-10 00:10:00+00:00  0.272727              2.0    17.295455  17.295455
# 2025-12-10 00:20:00+00:00  0.275862              2.0    17.229885  17.229885
# 2025-12-10 00:30:00+00:00  0.277992              2.0    17.138996  17.138996
# 2025-12-10 00:40:00+00:00  0.275862              2.0    17.183908  17.183908
# ...                             ...              ...          ...        ...
# 2025-12-18 12:50:00+00:00  4.398718              2.0     9.923077   9.923077
# 2025-12-18 13:00:00+00:00  4.486538              2.0     9.923077   9.923077
# 2025-12-18 13:10:00+00:00  4.590385              2.0     9.923077   9.923077
# 2025-12-18 13:20:00+00:00  4.339103              2.0     9.923077   9.923077
# 2025-12-18 13:30:00+00:00  4.411810              2.0     9.923077   9.923077
#
# ...
