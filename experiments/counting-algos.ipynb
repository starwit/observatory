# %% [markdown]
# ## How to get csv files for analysis below
# - Make sure your shells pwd is this directory
# - Connect to an analytics database
# - Run csv export (adjust the timestamp filter first)
#   ```psql
#   \copy (select * from areaoccupancy a join metadata m on m.id = a.metadata_id where a.occupancy_time > '2025-12-10' order by a.occupancy_time) to 'tsp-area.csv' with csv header
#   \copy (select * from linecrossing l join metadata m on m.id = l.metadata_id where l.crossing_time > '2025-12-10' order by l.crossing_time) to 'the-line.csv' with csv header
#   ```

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Whenever you change the code in imported modules, just rerun this cell, autoreload makes restarting the kernel unnecessary

from common import read_area_csv, read_line_csv

# %% [markdown]
# ## Counting algorithms

# %%
from datetime import datetime

import pandas as pd


def simple_counting(line_df: pd.DataFrame) -> pd.DataFrame:
    results = []
    count = 0
    for crossing in line_df.itertuples():
        if crossing.direction == 'in':
            count += 1
        else:
            count -= 1
        results.append([crossing.crossing_time, count])
    return pd.DataFrame(columns=['flow_occupancy_time', 'count'], data=results)

def lower_bounded_counting(line_df: pd.DataFrame) -> pd.DataFrame:
    results = []
    count = 0
    for crossing in line_df.itertuples():
        if crossing.direction == 'in':
            count += 1
        else:
            count = max(0, count - 1)
        results.append([crossing.crossing_time, count])
    return pd.DataFrame(columns=['flow_occupancy_time', 'count'], data=results)

def bounded_counting(line_df: pd.DataFrame, upper_bound: int) -> pd.DataFrame:
    results = []
    count = 0
    for crossing in line_df.itertuples():
        if crossing.direction == 'in':
            count = min(upper_bound, count + 1)
        else:
            count = max(0, count - 1)
        results.append([crossing.crossing_time, count])
    return pd.DataFrame(columns=['flow_occupancy_time', 'count'], data=results)

def bounded_counting_with_uncertainty(line_df: pd.DataFrame, upper_bound: int) -> pd.DataFrame:
    results = []
    p_in = 0.98
    p_out = 0.98
    lower_estimate = 0
    upper_estimate = 0

    for crossing in line_df.itertuples():
        if crossing.direction == 'in':
            lower_estimate = min(lower_estimate + p_in, upper_bound)
            upper_estimate = min(upper_estimate + 1, upper_bound)
        else:
            lower_estimate = max(lower_estimate - 1, 0)
            upper_estimate = max(upper_estimate - p_out, 0)
        results.append([crossing.crossing_time, lower_estimate, upper_estimate])
    return pd.DataFrame(columns=['flow_occupancy_time', 'lower_estimate', 'upper_estimate'], data=results)

def bounded_counting_with_idle_decrease(line_df: pd.DataFrame) -> pd.DataFrame:
    results = []
    count = 0
    previous_time = None
    
    for crossing in line_df.itertuples():
        if crossing.direction == 'in':
            count += 1
        else:
            count = max(0, count - 1)
        if previous_time is not None:
            time_diff_s = (crossing.crossing_time - previous_time).total_seconds()
            if time_diff_s > 3600:
                count = max(0, count - (time_diff_s // 900))
        results.append([crossing.crossing_time, count])
        previous_time = crossing.crossing_time
    return pd.DataFrame(columns=['flow_occupancy_time', 'count'], data=results)

# %% [markdown]
# ## Load data

# %%
MECKAUER_AREAS = [
    'parking-meckauer-west01',
    'parking-meckauer-west02',
    'parking-meckauer-west03',
    'parking-meckauer-center',
    'parking-meckauer-center02',
    'parking-meckauer-ost01',
    'parking-meckauer-ost02',
]
tsp_staging_area_df = read_area_csv('tsp-area.csv', MECKAUER_AREAS)
tsp_dev_area_df = read_area_csv('dev-area.csv', MECKAUER_AREAS)

tsp_staging_line_df = read_line_csv('tsp-line.csv', 'flow-meckauer-main')
tsp_staging_flow_df_simple = simple_counting(tsp_staging_line_df)
tsp_staging_flow_df_lower_bounded = lower_bounded_counting(tsp_staging_line_df)
tsp_staging_flow_df_bounded = bounded_counting(tsp_staging_line_df, upper_bound=75)

# %%
the_line_df = read_line_csv('2026-06-05_the-line.csv', 'theater-parking-flow', datetime.fromisoformat('2026-01-16T00:00:00Z'))

# %% [markdown]
# ## Plot results (count over time)

# %%
import plotly.graph_objects as go

the_line_df_simple = simple_counting(the_line_df)
the_line_df_lower_bounded = lower_bounded_counting(the_line_df)
the_line_df_bounded = bounded_counting(the_line_df, upper_bound=250)
the_line_df_bounded_with_idle_decrease = bounded_counting_with_idle_decrease(the_line_df)


fig = go.Figure()

# fig.add_trace(
#     go.Scattergl(
#         x=staging_area_df.index, 
#         y=staging_area_df['total_count'],
#         mode='lines',        # or "lines+markers"
#         name='area_occupancy (ground truth)'
#     ),
# )

def add_algo_result(df: pd.DataFrame, name: str):
    fig.add_trace(
        go.Scattergl(
            x=df['flow_occupancy_time'], 
            y=df['count'],
            mode='lines',        # or "lines+markers"
            name=name,
            line_shape='hv'
        ),
    )


# add_algo_result(staging_flow_df_simple, 'simple counting')
# add_algo_result(staging_flow_df_lower_bounded, 'lower bounded counting')
# add_algo_result(staging_flow_df_bounded, 'bounded counting (UB=75)')
add_algo_result(the_line_df_simple, 'the-line simple counting')
add_algo_result(the_line_df_bounded_with_idle_decrease, 'the-line bounded counting with idle decrease')
# add_algo_result(the_line_df_lower_bounded, 'the-line lower bounded counting')
# add_algo_result(the_line_df_bounded, 'the-line bounded counting (UB=250)')

fig.update_layout(
    title='Count over Time',
    xaxis_title='time',
    yaxis_title='total_count',
    height=600,
)
 
fig.show()

# %% [markdown]
# ## Analyze timestamp differences over time

# %%
import plotly.graph_objects as go

# Add a new column to the_line_df with the rolling max of timestamp differences
the_line_df_simple_diffs = pd.DataFrame({
    'timestamp_diff': the_line_df_simple['flow_occupancy_time'].diff().dt.total_seconds(),
    'flow_occupancy_time': the_line_df_simple['flow_occupancy_time']
})
the_line_df_simple_diffs = the_line_df_simple_diffs.set_index('flow_occupancy_time', drop=False)
the_line_df_simple_diffs = the_line_df_simple_diffs[~the_line_df_simple_diffs.index.duplicated(keep='first')]
the_line_df_simple_diffs['rolling_max_timestamp_diff'] = the_line_df_simple_diffs['timestamp_diff'].rolling(window='5min', min_periods=1).max()

the_line_df_simple_diffs

fig = go.Figure()

fig.add_trace(
    go.Scattergl(
        x=the_line_df_simple_diffs['flow_occupancy_time'], 
        y=the_line_df_simple_diffs['rolling_max_timestamp_diff']/60,
        mode='lines',        # or "lines+markers"
        line_shape='hv'
    ),
)


fig.update_layout(
    title='Rolling Max of Timestamp Differences',
    xaxis_title='time',
    yaxis_title='max timestamp diff (min)',
    height=600,
)
 
fig.show()
